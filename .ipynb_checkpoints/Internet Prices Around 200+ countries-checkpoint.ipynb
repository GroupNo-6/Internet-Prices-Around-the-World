# %% [markdown]
# # Reading the CSV Files

# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
file_one = "Resources/all_csv_sorted.csv"
file_two = "Resources/cities_internet_prices.19-10-2021.csv"
file_three = "Resources/internet_broadband_and_mobile_speeds_by_country.csv"

# %%
# Read our Data file with the pandas library
file_one_df = pd.read_csv(file_one)
file_two_df = pd.read_csv(file_two)
file_three_df = pd.read_csv(file_three)

# %%
# Show the first 5 rows
file_one_df.head()
# Out:
#    S.NO Country code     Country  Continental region  NO. OF Internet Plans  \
# 0     0           IL      Israel           NEAR EAST                   27.0
# 1     1           KG  Kyrgyzstan   CIS (FORMER USSR)                   20.0
# 2     2           FJ        Fiji             OCEANIA                   18.0
# 3     3           IT       Italy      WESTERN EUROPE                   29.0
# 4     4           SD       Sudan  SUB-SAHARAN AFRICA                   33.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.05                            0.02
# 1                       0.15                            0.10
# 2                       0.19                            0.05
# 3                       0.27                            0.09
# 4                       0.27                            0.03
#
#    Most expensive 1GB (USD) Average price of 1GB (USD  at the start of 2021)  \
# ...

# %%
# Show the first 5 rows
file_two_df.head()
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "InternetPrice"
# 0         66.441395
# 1         60.590455
# 2         68.988824
# 3         35.827084
# 4         66.690222

# %%
# Show the first 5 rows
file_three_df.head()
# Out:
#            Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0           Monaco                   1.0          192.68                NaN
# 1        Singapore                   2.0          192.01               19.0
# 2            Chile                   3.0          189.36              109.0
# 3         Thailand                   4.0          184.03               56.0
# 4  Hong Kong (SAR)                   5.0          173.42               38.0
#
#    Mobile Mbps         As of
# 0          NaN  January 2022
# 1        64.92  January 2022
# 2        15.50  January 2022
# 3        32.38  January 2022
# 4        45.86  January 2022

# %% [markdown]
# # Merging and Cleaning the dataframes
